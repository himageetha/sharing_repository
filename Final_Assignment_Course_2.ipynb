# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
#  **Hima G Gullapalli**
#  <br>
#       QA LEAD

# %% [markdown]
# *I am interested in Data Science because we could constantly learn and play through the data every day. Also the exciting element of this journey is always discover new things about the data.*

# %% [markdown]
# ### Adding 2 digits

# %%
128 + 128
# Out:
# 256

# %% [markdown]
# ***
# * Fruits
# * Flowers
# * Alphabets
#
#
# 1. Jupyter notebook
# 2. Zeppelin Notebood
# 3. IBM Watson
#
#
#
# | Student Name | Grade |
# |--------------|-------|
# |  Tarun  |A|
# |  Laila  |A+|
#
# https://www.google.com/
#
# <p style="font-size:20px">&#128540;</p>
#
#
# ```Doing code and syntax highlighting
# ```
#
#
#
# > ## Blockquoted header
# >
# > This is blockquoted text.
# >
# > This is a second paragraph within the blockquoted text.
#
#
# <br>
#
# ~~~strike through~~~
